# %% [markdown]
# # **Lab Assignment 4**

# %% [markdown]
# ## Personal Information
#
#  Author Name - Vijay Kumar Devalla,
#         ASU ID - 1229148936,
# Creation Date - February 8th, 2024

# %% [markdown]
# ### You must use this provided framework as-is and follow all the directions stated in there:
# *	Do NOT edit or otherwise change any part of this framework except the cells you have been instructed to code.
# *	You must NOT import any additional python packages to complete this assignment
#
# ### Note that, points will be deducted for notebooks that:
# *	do not follow the saving guidelines/naming convention
# *	do not compile/run
# *	do not follow all the instructions in the framework
# *	are incomplete
# *	have logical errors
# *	don’t result in the expected output

# %% [markdown]
# ## Exercise 1 (Gradient Descent)

# %% [markdown]
# * In this assignment, you will first use the gradient descent algorithm to find the optimal value of w1 which minimizes the given cost function (Steps 1.1 through 1.5). You will earn 5% points for each step and 25% in total.
#
# * You will run the algorithm for 4 different scenarios, each with a different value of alpha. For each scenario, you will log the responses in the last cell of this notebook (Step 1.6). You will earn 5% points for each scenario and 20%  in total.

# %%
# DO NOT edit this cell!
# You must use this cost function and its derivative as-is

# cost at particular value of w1
def calc_J(w1):
    return (5.5*w1*w1 - 1463*w1 + 100812.5)

# slope at particular value of w1
def calc_dJ_dw1(w1):
    return (11*w1 - 1463)

# %%
# First, complete coding Steps 1.1 through 1.5 in this cell.
# Then, run this cell for each of the four scenarios below,
# and log your responses for each scenario run in the next cell (Step 1.6)
alpha=0.08; niterations = 25; w1 = 60 # Scenario 1
#alpha=0.05; niterations = 25; w1 = 60 # Scenario 2
# alpha=0.15; niterations = 25; w1 = 60 # Scenario 3
# alpha=0.19; niterations = ,25; w1 = 60 # Scenario 4

# Step 1.1: calculate current value of J at current value of w1
J = calc_J(w1)


# Step 1.2: print w1 (rounded to 2 decimal places) and J (rounded to 2 decimal places)

print("w1 : ", round(w1,2))
print("J : ", round(J,2))


# run gradient descent for niterations
print("Alpha : ", alpha)
for i in range(niterations):

    # Step 1.3: calculate new value of w1
    print("\n*********** Interation ", i ," START *************")
    w1 = w1 - (alpha * calc_dJ_dw1(w1))


    # Step 1.4: calculate new value of J at new w1
    J = calc_J(w1)


    # Step 1.5: print w1 (rounded to 2 decimal places) and J (rounded to 2 decimal places)
    print("w1 : ", round(w1,2))
    print("J : ", round(J,2))

    print("\n*********** Interation ", i ," END *************")
# Out:
# w1 :  60
# J :  32832.5
# Alpha :  0.08
#
# *********** Interation  0  START *************
# w1 :  124.24
# J :  3945.06
#
# *********** Interation  0  END *************
#
# *********** Interation  1  START *************
# w1 :  131.95
# J :  3529.08
#
# *********** Interation  1  END *************
#
# *********** Interation  2  START *************
# w1 :  132.87
# J :  3523.09
#
# *********** Interation  2  END *************
#
# *********** Interation  3  START *************
# w1 :  132.98
# J :  3523.0
#
# *********** Interation  3  END *************
#
# *********** Interation  4  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  4  END *************
#
# *********** Interation  5  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  5  END *************
#
# *********** Interation  6  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  6  END *************
#
# *********** Interation  7  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  7  END *************
#
# *********** Interation  8  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  8  END *************
#
# *********** Interation  9  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  9  END *************
#
# *********** Interation  10  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  10  END *************
#
# *********** Interation  11  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  11  END *************
#
# *********** Interation  12  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  12  END *************
#
# *********** Interation  13  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  13  END *************
#
# *********** Interation  14  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  14  END *************
#
# *********** Interation  15  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  15  END *************
#
# *********** Interation  16  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  16  END *************
#
# *********** Interation  17  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  17  END *************
#
# *********** Interation  18  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  18  END *************
#
# *********** Interation  19  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  19  END *************
#
# *********** Interation  20  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  20  END *************
#
# *********** Interation  21  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  21  END *************
#
# *********** Interation  22  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  22  END *************
#
# *********** Interation  23  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  23  END *************
#
# *********** Interation  24  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  24  END *************

# %%
# First, complete coding Steps 1.1 through 1.5 in this cell.
# Then, run this cell for each of the four scenarios below,
# and log your responses for each scenario run in the next cell (Step 1.6)
#alpha=0.08; niterations = 25; w1 = 60 # Scenario 1
alpha=0.05; niterations = 25; w1 = 60 # Scenario 2
# alpha=0.15; niterations = 25; w1 = 60 # Scenario 3
# alpha=0.19; niterations = ,25; w1 = 60 # Scenario 4

# Step 1.1: calculate current value of J at current value of w1
J = calc_J(w1)


# Step 1.2: print w1 (rounded to 2 decimal places) and J (rounded to 2 decimal places)

print("w1 : ", round(w1,2))
print("J : ", round(J,2))

print("Alpha : ", alpha)
# run gradient descent for niterations
    
for i in range(niterations):

    # Step 1.3: calculate new value of w1
    print("\n*********** Interation ", i ," START *************")
    w1 = w1 - (alpha * calc_dJ_dw1(w1))


    # Step 1.4: calculate new value of J at new w1
    J = calc_J(w1)


    # Step 1.5: print w1 (rounded to 2 decimal places) and J (rounded to 2 decimal places)
    print("w1 : ", round(w1,2))
    print("J : ", round(J,2))

    print("\n*********** Interation ", i ," END *************")
# Out:
# w1 :  60
# J :  32832.5
# Alpha :  0.05
#
# *********** Interation  0  START *************
# w1 :  100.15
# J :  9458.17
#
# *********** Interation  0  END *************
#
# *********** Interation  1  START *************
# w1 :  118.22
# J :  4724.87
#
# *********** Interation  1  END *************
#
# *********** Interation  2  START *************
# w1 :  126.35
# J :  3766.38
#
# *********** Interation  2  END *************
#
# *********** Interation  3  START *************
# w1 :  130.01
# J :  3572.28
#
# *********** Interation  3  END *************
#
# *********** Interation  4  START *************
# w1 :  131.65
# J :  3532.98
#
# *********** Interation  4  END *************
#
# *********** Interation  5  START *************
# w1 :  132.39
# J :  3525.02
#
# *********** Interation  5  END *************
#
# *********** Interation  6  START *************
# w1 :  132.73
# J :  3523.41
#
# *********** Interation  6  END *************
#
# *********** Interation  7  START *************
# w1 :  132.88
# J :  3523.08
#
# *********** Interation  7  END *************
#
# *********** Interation  8  START *************
# w1 :  132.94
# J :  3523.02
#
# *********** Interation  8  END *************
#
# *********** Interation  9  START *************
# w1 :  132.98
# J :  3523.0
#
# *********** Interation  9  END *************
#
# *********** Interation  10  START *************
# w1 :  132.99
# J :  3523.0
#
# *********** Interation  10  END *************
#
# *********** Interation  11  START *************
# w1 :  132.99
# J :  3523.0
#
# *********** Interation  11  END *************
#
# *********** Interation  12  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  12  END *************
#
# *********** Interation  13  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  13  END *************
#
# *********** Interation  14  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  14  END *************
#
# *********** Interation  15  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  15  END *************
#
# *********** Interation  16  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  16  END *************
#
# *********** Interation  17  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  17  END *************
#
# *********** Interation  18  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  18  END *************
#
# *********** Interation  19  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  19  END *************
#
# *********** Interation  20  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  20  END *************
#
# *********** Interation  21  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  21  END *************
#
# *********** Interation  22  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  22  END *************
#
# *********** Interation  23  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  23  END *************
#
# *********** Interation  24  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  24  END *************

# %%
# First, complete coding Steps 1.1 through 1.5 in this cell.
# Then, run this cell for each of the four scenarios below,
# and log your responses for each scenario run in the next cell (Step 1.6)
#alpha=0.08; niterations = 25; w1 = 60 # Scenario 1
#alpha=0.05; niterations = 25; w1 = 60 # Scenario 2
alpha=0.15; niterations = 25; w1 = 60 # Scenario 3
# alpha=0.19; niterations = ,25; w1 = 60 # Scenario 4

# Step 1.1: calculate current value of J at current value of w1
J = calc_J(w1)

print("Alpha : ", alpha)
# Step 1.2: print w1 (rounded to 2 decimal places) and J (rounded to 2 decimal places)

print("w1 : ", round(w1,2))
print("J : ", round(J,2))


# run gradient descent for niterations
    
for i in range(niterations):

    # Step 1.3: calculate new value of w1
    print("\n*********** Interation ", i ," START *************")
    w1 = w1 - (alpha * calc_dJ_dw1(w1))


    # Step 1.4: calculate new value of J at new w1
    J = calc_J(w1)


    # Step 1.5: print w1 (rounded to 2 decimal places) and J (rounded to 2 decimal places)
    print("w1 : ", round(w1,2))
    print("J : ", round(J,2))

    print("\n*********** Interation ", i ," END *************")
# Out:
# Alpha :  0.15
# w1 :  60
# J :  32832.5
#
# *********** Interation  0  START *************
# w1 :  180.45
# J :  15906.26
#
# *********** Interation  0  END *************
#
# *********** Interation  1  START *************
# w1 :  102.16
# J :  8754.93
#
# *********** Interation  1  END *************
#
# *********** Interation  2  START *************
# w1 :  153.05
# J :  5733.49
#
# *********** Interation  2  END *************
#
# *********** Interation  3  START *************
# w1 :  119.97
# J :  4456.93
#
# *********** Interation  3  END *************
#
# *********** Interation  4  START *************
# w1 :  141.47
# J :  3917.59
#
# *********** Interation  4  END *************
#
# *********** Interation  5  START *************
# w1 :  127.49
# J :  3689.71
#
# *********** Interation  5  END *************
#
# *********** Interation  6  START *************
# w1 :  136.58
# J :  3593.44
#
# *********** Interation  6  END *************
#
# *********** Interation  7  START *************
# w1 :  130.67
# J :  3552.76
#
# *********** Interation  7  END *************
#
# *********** Interation  8  START *************
# w1 :  134.51
# J :  3535.57
#
# *********** Interation  8  END *************
#
# *********** Interation  9  START *************
# w1 :  132.02
# J :  3528.31
#
# *********** Interation  9  END *************
#
# *********** Interation  10  START *************
# w1 :  133.64
# J :  3525.24
#
# *********** Interation  10  END *************
#
# *********** Interation  11  START *************
# w1 :  132.58
# J :  3523.95
#
# *********** Interation  11  END *************
#
# *********** Interation  12  START *************
# w1 :  133.27
# J :  3523.4
#
# *********** Interation  12  END *************
#
# *********** Interation  13  START *************
# w1 :  132.82
# J :  3523.17
#
# *********** Interation  13  END *************
#
# *********** Interation  14  START *************
# w1 :  133.11
# J :  3523.07
#
# *********** Interation  14  END *************
#
# *********** Interation  15  START *************
# w1 :  132.93
# J :  3523.03
#
# *********** Interation  15  END *************
#
# *********** Interation  16  START *************
# w1 :  133.05
# J :  3523.01
#
# *********** Interation  16  END *************
#
# *********** Interation  17  START *************
# w1 :  132.97
# J :  3523.01
#
# *********** Interation  17  END *************
#
# *********** Interation  18  START *************
# w1 :  133.02
# J :  3523.0
#
# *********** Interation  18  END *************
#
# *********** Interation  19  START *************
# w1 :  132.99
# J :  3523.0
#
# *********** Interation  19  END *************
#
# *********** Interation  20  START *************
# w1 :  133.01
# J :  3523.0
#
# *********** Interation  20  END *************
#
# *********** Interation  21  START *************
# w1 :  132.99
# J :  3523.0
#
# *********** Interation  21  END *************
#
# *********** Interation  22  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  22  END *************
#
# *********** Interation  23  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  23  END *************
#
# *********** Interation  24  START *************
# w1 :  133.0
# J :  3523.0
#
# *********** Interation  24  END *************

# %%
# First, complete coding Steps 1.1 through 1.5 in this cell.
# Then, run this cell for each of the four scenarios below,
# and log your responses for each scenario run in the next cell (Step 1.6)
#alpha=0.08; niterations = 25; w1 = 60 # Scenario 1
#alpha=0.05; niterations = 25; w1 = 60 # Scenario 2
#alpha=0.15; niterations = 25; w1 = 60 # Scenario 3
alpha=0.19; niterations = 25; w1 = 60 # Scenario 4

# Step 1.1: calculate current value of J at current value of w1
J = calc_J(w1)


# Step 1.2: print w1 (rounded to 2 decimal places) and J (rounded to 2 decimal places)
print("Alpha : ", alpha)
print("w1 : ", round(w1,2))
print("J : ", round(J,2))


# run gradient descent for niterations
    
for i in range(niterations):

    # Step 1.3: calculate new value of w1
    print("\n*********** Interation ", i ," START *************")
    w1 = w1 - (alpha * calc_dJ_dw1(w1))


    # Step 1.4: calculate new value of J at new w1
    J = calc_J(w1)


    # Step 1.5: print w1 (rounded to 2 decimal places) and J (rounded to 2 decimal places)
    print("w1 : ", round(w1,2))
    print("J : ", round(J,2))

    print("\n*********** Interation ", i ," END *************")
# Out:
# Alpha :  0.19
# w1 :  60
# J :  32832.5
#
# *********** Interation  0  START *************
# w1 :  212.57
# J :  38345.62
#
# *********** Interation  0  END *************
#
# *********** Interation  1  START *************
# w1 :  46.27
# J :  44895.75
#
# *********** Interation  1  END *************
#
# *********** Interation  2  START *************
# w1 :  227.54
# J :  52677.97
#
# *********** Interation  2  END *************
#
# *********** Interation  3  START *************
# w1 :  29.95
# J :  61924.01
#
# *********** Interation  3  END *************
#
# *********** Interation  4  START *************
# w1 :  245.32
# J :  72909.25
#
# *********** Interation  4  END *************
#
# *********** Interation  5  START *************
# w1 :  10.57
# J :  85960.8
#
# *********** Interation  5  END *************
#
# *********** Interation  6  START *************
# w1 :  266.45
# J :  101467.35
#
# *********** Interation  6  END *************
#
# *********** Interation  7  START *************
# w1 :  -12.46
# J :  119890.68
#
# *********** Interation  7  END *************
#
# *********** Interation  8  START *************
# w1 :  291.55
# J :  141779.44
#
# *********** Interation  8  END *************
#
# *********** Interation  9  START *************
# w1 :  -39.82
# J :  167785.48
#
# *********** Interation  9  END *************
#
# *********** Interation  10  START *************
# w1 :  321.37
# J :  198683.25
#
# *********** Interation  10  END *************
#
# *********** Interation  11  START *************
# w1 :  -72.32
# J :  235392.89
#
# *********** Interation  11  END *************
#
# *********** Interation  12  START *************
# w1 :  356.8
# J :  279007.62
#
# *********** Interation  12  END *************
#
# *********** Interation  13  START *************
# w1 :  -110.95
# J :  330826.28
#
# *********** Interation  13  END *************
#
# *********** Interation  14  START *************
# w1 :  398.9
# J :  392392.02
#
# *********** Interation  14  END *************
#
# *********** Interation  15  START *************
# w1 :  -156.83
# J :  465538.29
#
# *********** Interation  15  END *************
#
# *********** Interation  16  START *************
# w1 :  448.92
# J :  552443.36
#
# *********** Interation  16  END *************
#
# *********** Interation  17  START *************
# w1 :  -211.35
# J :  655695.28
#
# *********** Interation  17  END *************
#
# *********** Interation  18  START *************
# w1 :  508.34
# J :  778368.89
#
# *********** Interation  18  END *************
#
# *********** Interation  19  START *************
# w1 :  -276.12
# J :  924117.4
#
# *********** Interation  19  END *************
#
# *********** Interation  20  START *************
# w1 :  578.94
# J :  1097281.2
#
# *********** Interation  20  END *************
#
# *********** Interation  21  START *************
# w1 :  -353.08
# J :  1303017.12
#
# *********** Interation  21  END *************
#
# *********** Interation  22  START *************
# w1 :  662.82
# J :  1547451.97
#
# *********** Interation  22  END *************
#
# *********** Interation  23  START *************
# w1 :  -444.51
# J :  1837865.0
#
# *********** Interation  23  END *************
#
# *********** Interation  24  START *************
# w1 :  762.48
# J :  2182904.73
#
# *********** Interation  24  END *************

# %%
# Step 1.6: for each Scenario, answer the following questions based on the output (20%)
# type your answers below for each question
#
### Scenario 1 (alpha=0.08; niterations = 25; w1 = 60):
# did the cost steadily decrease as training progressed?
Yes, the cost steadily decreased from 32832.5 to 3523.0.

# did the gradient descent algorithm converge?
Yes, the algorithm converged to a stable value of w1 and J.

# what is the minimum cost?
The minimum cost is 3523.0.

# what is the optimal value of w1?
The optimal value of w1 is 133.0.

# in how many iterations did gradient descent converge (at which row # in the output)?
Convergence appeared to occur around iteration 9 to 10 (rows 18 to 20 in the output), where the values of w1 and J stabilize.

#
### Scenario 2 (alpha=0.05; niterations = 25; w1 = 60):
# did the cost steadily decrease as training progressed?
Yes, similar to Scenario 1, the cost steadily decreased.

# did the gradient descent algorithm converge?
Yes, it converged similarly to Scenario 1.

# what is the minimum cost?
The minimum cost again is 3523.0.

# what is the optimal value of w1?
The optimal value of w1 is 133.0, the same as in Scenario 1.

# in how many iterations did gradient descent converge (at which row # in the output)?
Convergence appeared to occur around the same point as in Scenario 1, around iteration 9 to 10 (rows 18 to 20 in the output).
#
### Scenario 3 (alpha=0.15; niterations = 25; w1 = 60):
# did the cost steadily decrease as training progressed?
Initially, there was a significant fluctuation, but eventually, the cost started to decrease more steadily.

# did the gradient descent algorithm converge?
Yes, but the path to convergence showed more volatility compared to the lower alpha values.

# what is the minimum cost?
The minimum cost approached 3523.0, similar to the previous scenarios.

# what is the optimal value of w1?
The optimal value of w1 approached 133.0, showing that despite the initial fluctuations, it converged to a similar value.

# in how many iterations did gradient descent converge (at which row # in the output)?
It showed signs of settling around iteration 18 to 19 (rows 36 to 38 in the output), but with more oscillation before reaching stability.

#
### Scenario 4 (alpha=0.19; niterations = 25; w1 = 60):
# did the cost steadily decrease as training progressed?
No, the cost increased dramatically, indicating divergence.

# did the gradient descent algorithm converge?
No, the algorithm did not converge; instead, it diverged.

# what is the minimum cost?
There is no minimum cost in the traditional sense as the cost increased due to divergence.

# what is the optimal value of w1?
There was no optimal value of w1 identified as the algorithm diverged.

# in how many iterations did gradient descent converge (at which row # in the output)?
The algorithm did not converge within the given iterations; it diverged instead.

# %% [markdown]
# ## Exercise 2 (Single Neuron)

# %% [markdown]
# ### Then, you will apply deep learning thinking in modeling a single neuron to build logistic regression and linear regression models. You need also to Apply the idea of vectorization to efficiently train your models and implement gradient descent from scratch (using multiple iterations of the forward pass, backward propagation, and gradient descent steps) to minimize the loss functions and determine model parameters.
#
# ### Specifically, there are two parts in this assignment:
# * In the first part, you will train a logistic regression model using the breast cancer data set. This part has 7 parts (2.1.1 through 2.1.7) that you will need to code (see framework for more details).
# * In the second part, you will train a linear regression model using the diabetes data set. This part has 7 parts (2.2.1 through 2.2.7) that you will need to code (see framework for more details).

# %%
### DO NOT EDIT THIS CELL!!!
### DO NOT IMPORT ANY ADDITIONAL PACKAGES

import numpy as np
import scipy
from sklearn import metrics
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### PART 1
#
# * Logistic Regression for Binary Classification using the breast cancer dataset
#
# * We aren't going to preprocess data or split into train/test since the focus here is purely on the gradient descent algorithm
#
# * NOTE: YOU WILL ONLY EDIT ONE CELL FOR PART-1 (SEE BELOW) (5% for each step, but 25% in total)

# %%
### DO NOT EDIT THIS CELL!!!

# read the breast cancer dataset from sklearn
from sklearn.datasets import load_breast_cancer

dataset = load_breast_cancer()

# feature matrix X: mxn
X = dataset.data
print ("X: ", X.shape)

# target vector y: mx1
y = dataset.target
y = y.reshape(y.shape[0], 1)
print ("y: ", y.shape)

# number of samples: m
m = X.shape[0]
print ("m: ", m)

# number of features: n
n = X.shape[1]
features = dataset.feature_names
print ("n: ",n)
print ("features: ", features)
# Out:
# X:  (569, 30)
# y:  (569, 1)
# m:  569
# n:  30
# features:  ['mean radius' 'mean texture' 'mean perimeter' 'mean area'
#  'mean smoothness' 'mean compactness' 'mean concavity'
#  'mean concave points' 'mean symmetry' 'mean fractal dimension'
#  'radius error' 'texture error' 'perimeter error' 'area error'
#  'smoothness error' 'compactness error' 'concavity error'
#  'concave points error' 'symmetry error' 'fractal dimension error'
#  'worst radius' 'worst texture' 'worst perimeter' 'worst area'
#  'worst smoothness' 'worst compactness' 'worst concavity'
#  'worst concave points' 'worst symmetry' 'worst fractal dimension']

# %%
### THIS IS THE ONLY CELL YOU MUST EDIT FOR PART-1

# train the logistic regression model

# initializae hyperparameters nepochs and alpha
nepochs = 5000
alpha = 2.5e-6

# initialize model parameters w and b
w = np.zeros((n,1))
b = 0

# this list will collect loss for each iteration
costs = []

# repeat for nepochs
### (2.1.1) YOUR CODE HERE
# for....
for epoch in range(nepochs):

    # forward pass (calculate current loss)
    ### (2.1.2) YOUR CODE HERE
    z = np.dot(X, w) + b
    yhat = 1 / (1 + np.exp(-z))  # Sigmoid function
    

    # backward propagation (calculate current gradient)
    ### (2.1.3) YOUR CODE HERE
    dz = yhat - y
    dw = 1/m * np.dot(X.T, dz)
    db = 1/m * np.sum(dz)


    # gradient descent (update parameters)
    ### (2.1.4) YOUR CODE HERE
    w = w - alpha * dw
    b = b - alpha * db

    # append loss to costs: This step is done to keep track of how the loss changes over the course of training
    # Costs: It is likely initialized as an empty list before the training loop. It is used to store the loss values at each iteration.
    ### (2.1.5) YOUR CODE HERE
    cost = -1/m * np.sum(y * np.log(yhat) + (1 - y) * np.log(1 - yhat))
    costs.append(cost)
    if epoch % 1000 == 0:
        print(f"Cost after iteration {epoch}: {cost}")


# use final parameters w and b to calcualte accuracy for training data X, y
#  - do a single forward pass for X: calcualte z, yhat
#  - set yhat to round(yhat) (that is, thresholding binary classification prediction at 0.5)
#  - calcualte metrics.accuracy_score(y, yhat) and print it
### (2.1.6) YOUR CODE HERE

z = np.dot(X, w) + b
yhat = 1 / (1 + np.exp(-z))  # Sigmoid function to get probabilities
predictions = np.round(yhat)  # Convert probabilities to binary predictions

accuracy = metrics.accuracy_score(y, predictions)
print(f"Accuracy: {accuracy}")


# use plt.plot(costs)  to plot  costs against iterations and show the plot
### (2.1.7) YOUR CODE HERE
plt.plot(costs)
plt.ylabel('Cost')
plt.xlabel('Iterations')
plt.title('Cost reduction over time')
plt.show()
# Out:
# Cost after iteration 0: 0.6931471805599453
# Cost after iteration 1000: 0.3603157216481866
# Cost after iteration 2000: 0.30121798765108737
# Cost after iteration 3000: 0.27338502048782015
# Cost after iteration 4000: 0.2572043756030124
# Accuracy: 0.9191564147627417

# %%
### DO NOT EDIT THIS CELL!!!

# compare results from your implementation to that of SGDClassifier
# your accuracy score above should match (or be very close to) what you get from here

nepochs = 5000
alpha = 2.5e-6
y = y.reshape(y.shape[0],) # to avoid warning

from sklearn.linear_model import SGDClassifier
clf = SGDClassifier(loss='log_loss', # loss function for logistic regression
                    penalty=None, alpha=0, # no regularization
                    max_iter=nepochs, tol=None, # stop based only on nepochs
                    shuffle=False, random_state=0, # don't shuffle, use random state to replicate results
                    learning_rate='constant', eta0=alpha) # constant learning rate of alpha
clf.fit(X,y)
print (round(clf.score(X,y),2))
# Out:
# 0.92

# %% [markdown]
# ### Part 2
#
# * Linear Regression using the diabetes dataset
#
# * We aren't going to preprocess data or split  into train/test since the focus here is purely on the gradient descent algorithm
#
# * NOTE: YOU WILL ONLY EDIT ONE CELL FOR PART-2 (SEE BELOW) (5% for each step, but 25% in total)

# %%
### DO NOT EDIT THIS CELL!!!

# read the diabetes dataset from sklearn
from sklearn.datasets import load_diabetes

dataset = load_diabetes()

# feature matrix X: mxn
X = dataset.data
print ("X: ", X.shape)

# target vector y: mx1
y = dataset.target
y = y.reshape(y.shape[0], 1)
print ("y: ", y.shape)

# number of samples: m
m = X.shape[0]
print ("m: ", m)

# number of features: n
n = X.shape[1]
features = dataset.feature_names
print ("n: ",n)
print ("features: ", features)
# Out:
# X:  (442, 10)
# y:  (442, 1)
# m:  442
# n:  10
# features:  ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
### THIS IS THE ONLY CELL YOU MUST EDIT FOR PART-2

# train the linear regression model

# initialize hyperparameters nepochs and alpha
nepochs = 5000
alpha = 0.5

# initialize model paramters w and b
w = np.zeros((n,1))
b = 0

# this list will collect loss for each iteration
costs = []

# repeat for nepochs
### (2.2.1) YOUR CODE HERE
# for ...
for epoch in range(nepochs):

    # forward pass (calculate current loss)
    ### (2.2.2) YOUR CODE HERE
    z = np.dot(X, w) + b
    yhat = z  # For linear regression, output is directly the weighted sum



    # backward propagation (calculate current gradient)
    ### (2.2.3) YOUR CODE HERE
    dz = yhat - y
    dw = 1/m * np.dot(X.T, dz)
    db = 1/m * np.sum(dz)


    # gradient descent (update parameters)
    ### (2.2.4) YOUR CODE HERE
    w = w - alpha * dw
    b = b - alpha * db


    # append loss to costs: This step is done to keep track of how the loss changes over the course of training
    # Costs: It is likely initialized as an empty list before the training loop. It is used to store the loss values at each iteration.
    ### (2.2.5) YOUR COD HERE
    cost = 1/(2*m) * np.sum(np.square(dz))
    costs.append(cost)
    if epoch % 1000 == 0:
        print(f"Cost after iteration {epoch}: {cost}")


# use final parameters w and b to calcualte mse and r2 for training data X, y
#  - do a single forward pass for X: calcualte z, yhat
#  - calculate metrics.mean_squared_error(y, yhat) and print it
#  - calculate metrics.r2_score(y, yhat) and print it
### (2.2.6) YOUR CODE HERE
    
    z = np.dot(X, w) + b
    yhat = z  # For linear regression, output is directly the weighted sum

    mse = metrics.mean_squared_error(y, yhat)
    r2 = metrics.r2_score(y, yhat)

    print(f"MSE: {mse}")
    print(f"R^2 score: {r2}")


# use plt.plot(costs) to plot costs against iterations and show the plot
### (2.2.7) YOUR CODE HERE
plt.plot(costs)
plt.ylabel('Cost')
plt.xlabel('Iterations')
plt.title('Cost reduction over time')
plt.show()
# Out:
# Cost after iteration 0: 14537.240950226245
# MSE: 11696.501253534003
# R^2 score: -0.9724668280877038
# MSE: 7337.514701612145
# R^2 score: -0.23737894228523237
# MSE: 6233.393993415862
# R^2 score: -0.05118296590606919
# MSE: 5943.106035833082
# R^2 score: -0.002229577665088911
# MSE: 5856.3915345584455
# R^2 score: 0.012393724942322049
# MSE: 5820.6846541713
# R^2 score: 0.0184152381770476
# MSE: 5797.842933072041
# R^2 score: 0.022267205204461793
# MSE: 5778.32976213377
# R^2 score: 0.025557854395382495
# MSE: 5759.760004283564
# R^2 score: 0.028689408915079873
# MSE: 5741.536399316862
# R^2 score: 0.03176258913417607
# MSE: 5723.508665020863
# R^2 score: 0.03480273824489355
# MSE: 5705.638272375926
# R^2 score: 0.037816353678516546
# MSE: 5687.914639277179
# R^2 score: 0.040805219973034546
# MSE: 5670.334178886887
# R^2 score: 0.04376994200321305
# MSE: 5652.895061645236
# R^2 score: 0.046710828301147256
# MSE: 5635.595905696408
# R^2 score: 0.049628111899323035
# MSE: 5618.435449419184
# R^2 score: 0.05252200555418396
# MSE: 5601.412469484352
# R^2 score: 0.055392715564710704
# MSE: 5584.5257602945285
# R^2 score: 0.05824044523963612
# MSE: 5567.774128770221
# R^2 score: 0.061065395776709
# MSE: 5551.1563929731565
# R^2 score: 0.0638677664948527
# MSE: 5534.671381689571
# R^2 score: 0.06664775490443797
# MSE: 5518.317934254151
# R^2 score: 0.0694055567369729
# MSE: 5502.0949004347885
# R^2 score: 0.07214136596453735
# MSE: 5486.001140333202
# R^2 score: 0.07485537481654236
# MSE: 5470.035524290135
# R^2 score: 0.07754777379571742
# MSE: 5454.1969327923625
# R^2 score: 0.08021875169379189
# MSE: 5438.4842563807515
# R^2 score: 0.08286849560699949
# MSE: 5422.8963955592435
# R^2 score: 0.08549719095142849
# MSE: 5407.432260704644
# R^2 score: 0.08810502147823296
# MSE: 2880.517837537223
# R^2 score: 0.5142371415947644
# MSE: 2880.5171534169876
# R^2 score: 0.5142372569629794
# MSE: 2880.516469635637
# R^2 score: 0.5142373722740458
# MSE: 2880.5157861926964
# R^2 score: 0.5142374875280435
# MSE: 2880.5151030876973
# R^2 score: 0.5142376027250517
# MSE: 2880.5144203201676
# R^2 score: 0.5142377178651499
# MSE: 2880.513737889639
# R^2 score: 0.5142378329484172
# MSE: 2880.5130557956404
# R^2 score: 0.514237947974933
# MSE: 2880.512374037705
# R^2 score: 0.514238062944776
# MSE: 2880.511692615365
# R^2 score: 0.514238177858025
# MSE: 2880.5110115281536
# R^2 score: 0.5142382927147588
# MSE: 2880.510330775604
# R^2 score: 0.5142384075150562
# MSE: 2880.509650357251
# R^2 score: 0.5142385222589956
# MSE: 2880.5089702726314
# R^2 score: 0.5142386369466551
# MSE: 2880.5082905212794
# R^2 score: 0.514238751578113
# MSE: 2880.5076111027333
# R^2 score: 0.5142388661534477
# MSE: 2880.50693201653
# R^2 score: 0.5142389806727369
# MSE: 2880.506253262208
# R^2 score: 0.5142390951360585
# MSE: 2880.505574839306
# R^2 score: 0.5142392095434902
# MSE: 2880.5048967473645
# R^2 score: 0.5142393238951098
# MSE: 2880.5042189859228
# R^2 score: 0.5142394381909947
# MSE: 2880.5035415545235
# R^2 score: 0.5142395524312222
# MSE: 2880.502864452708
# R^2 score: 0.5142396666158695
# MSE: 2880.502187680018
# R^2 score: 0.5142397807450139
# MSE: 2880.5015112359984
# R^2 score: 0.5142398948187323
# MSE: 2880.500835120192
# R^2 score: 0.5142400088371017
# MSE: 2880.500159332144
# R^2 score: 0.5142401228001987
# MSE: 2880.499483871401
# R^2 score: 0.5142402367080998
# MSE: 2880.4988087375077
# R^2 score: 0.514240350560882
# MSE: 2880.498133930012
# R^2 score: 0.5142404643586214
# MSE: 2880.497459448461
# R^2 score: 0.5142405781013942
# MSE: 2880.4967852924033
# R^2 score: 0.5142406917892768
# MSE: 2880.4961114613884
# R^2 score: 0.514240805422345
# MSE: 2880.4954379549654
# R^2 score: 0.5142409190006749
# MSE: 2880.494764772686
# R^2 score: 0.5142410325243421
# MSE: 2880.4940919140995
# R^2 score: 0.5142411459934224

# %%
### DO NOT EDIT THIS CELL!!!

# compare results from our implementation to that of SGDRegressor
# your mse and r2 score above should match (or be very close to) what you get from here

nepochs = 5000
alpha = 0.5
y = y.reshape(y.shape[0],) # to avoid warning

from sklearn.linear_model import SGDRegressor
clf = SGDRegressor(loss='squared_error', # mse for linear regression
                    penalty=None, alpha=0, # no regularization
                    max_iter=nepochs, tol=None, # stop based on only on nepochs
                    shuffle=False, random_state=0, # don't shuffle, use random state to replicate results
                    learning_rate='constant', eta0=alpha) # constant learning rate of alpha
clf.fit(X,y)
yhat = clf.predict(X)
print (round(metrics.mean_squared_error(y, yhat),2))
print (round(clf.score(X,y),2))
# Out:
# 2922.89
# 0.51

# %% [markdown]
# ## Acknowledgment
#
# I have used chatgpt to understand the code and use of the parameters in the above functions.
